# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from scipy import stats  
import glob

import report
import pbreport
import calibtools

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['figure.figsize']=(12,8)
matplotlib.rcParams['legend.fontsize']=20

# %%
pb=pbreport.Report('PB_AMAC_E09')

# %%
pb.render_general()
# Out:
# <html><body><table><tr><th></th><th>AMAC [counts]</th></tr><tr><td><b>OTA left</b></td><td>789</td></tr><tr><td><b>OTA right</b></td><td>700</td></tr><tr><td><b>DVD/2</b></td><td>693</td></tr><tr><td><b>BGO</b></td><td>591</td></tr><tr><td><b>Ibase</b></td><td>0.3932137</td></tr></table></body></html>

# %%
pb.render_dcdceff()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-9ce20e2113a4> in <module>()
# ----> 1 pb.render_dcdceff()
#
# /global/u2/k/kkrizka/ITkStrips/AMAC/pbreport.py in render_dcdceff(self)
#     171
#     172     def render_dcdceff(self):
# --> 173         eff2A=self.dcdceff[self.dcdceff.Iout==2000].eff.iloc[0]
#     174
#     175         plt.plot(self.dcdceff.Iout,self.dcdceff.eff)
#
# /usr/common/software/python/3.6-anaconda-4.4/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /usr/common/software/python/3.6-anaconda-4.4/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1828
# ...

# %%
pb.render_vin()

# %%
pb.render_viniin()

# %%
pb.render_iout()

# %%
pb.render_ileak()

# %%
pb.render_coil()

# %%
pb.dcdceff
