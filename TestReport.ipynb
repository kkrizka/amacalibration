# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

import report

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['figure.figsize']=(12,8)
matplotlib.rcParams['legend.fontsize']=20

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
r=report.Report('AMAC_G02')

# %%
r.render_genparam()
# Out:
# <html><body><table><tr><th></th><th>1.50</th><th>2.00</th><th>2.50</th><th>3.00</th></tr><tr><td>Supply Current [mA] (reset state)</td><td style="color: red">0.044080 (0.004430)</td><td style="color: orange">0.044394 (0.001965)</td><td style="color: orange">0.044349 (0.001984)</td><td style="color: orange">0.044416 (0.001918)</td></tr><tr><td>VDD [V] (reset state)</td><td style="color: black">1.412580 (0.000000)</td><td style="color: black">1.412580 (0.000000)</td><td style="color: black">1.409730 (0.001002)</td><td style="color: black">1.410240 (0.001422)</td></tr><tr><td>Supply Current [mA] (run state)</td><td style="color: red">0.028335 (0.003983)</td><td style="color: red">0.028434 (0.003632)</td><td style="color: red">0.027959 (0.003666)</td><td style="color: red">0.028063 (0.003680)</td></tr><tr><td>VDD [V] (run state)</td><td style="color: black">1.178750 (0.000000)</td><td style="color: black">1.178910 (0.000698)</td><td style="color: black">1.179810 (0.001506)</td><td style="color: black">1.179840 (0.001517)</td></tr><tr><td>VDD/2 (AM CH0 right)</td><td style="color: black">492.900000 (0.300000)</td><td style="color: black">491.900000 (0.300000)</td><td style="color: black">490.600000 (0.489898)</td><td style="color: black">490.600000 (0.489898)</td></tr><tr><td>VDD/2 (AM CH0 left)</td><td style="color: black">520.500000 (0.500000)</td><td style="color: black">519.600000 (0.489898)</td><td style="color: black">518.000000 (0.000000)</td><td style="color: black">517.800000 (0.400000)</td></tr><tr><td>DVDD/2 (AM CH1 left)</td><td style="color: black">655.000000 (0.000000)</td><td style="color: black">653.400000 (0.489898)</td><td style="color: black">652.000000 (0.000000)</td><td style="color: black">652.200000 (0.400000)</td></tr><tr><td>Bandgap ref (AM CH2 left)</td><td style="color: black">551.700000 (0.458258)</td><td style="color: black">551.100000 (0.300000)</td><td style="color: black">550.000000 (0.000000)</td><td style="color: black">550.100000 (0.300000)</td></tr><tr><td>Temp Voltage (AM CH4 left)</td><td style="color: black">568.700000 (0.458258)</td><td style="color: black">568.200000 (0.400000)</td><td style="color: black">567.200000 (0.400000)</td><td style="color: black">567.200000 (0.400000)</td></tr><tr><td>VDD_H/4 (AM CH4 right)</td><td style="color: black">313.000000 (0.000000)</td><td style="color: black">407.500000 (0.500000)</td><td style="color: black">503.100000 (0.300000)</td><td style="color: black">597.900000 (0.300000)</td></tr><tr><td>OTA (AM CH5 right)</td><td style="color: black">688.100000 (0.300000)</td><td style="color: black">687.600000 (0.489898)</td><td style="color: black">686.500000 (0.500000)</td><td style="color: black">687.000000 (0.000000)</td></tr><tr><td>OTA (AM CH5 left)</td><td style="color: black">733.000000 (0.000000)</td><td style="color: black">732.200000 (0.400000)</td><td style="color: black">730.400000 (0.489898)</td><td style="color: black">731.000000 (0.447214)</td></tr></table></body></html>

# %%
r.render_i2c()

# %%
r.render_bgo()
# Out:
# Best BGO setting is 9

# %%
r.render_noise()
# Out:
# CH0_L 520.008 0.252982212813
# CH0_R 492.69 0.467031174675
# CH1_R 490.088 0.400520182284
# CH2_R 492.199 0.42376712777
# CH3_L_Gain1 522.933 0.250147103868
# CH3_L_Gain23 517.995 0.0947838804016
# CH3_R_Gain1 490.061 0.404280153412
# CH3_R_Gain23 481.488 0.50010609485

# %%
r.render_calib_rampgain()

# %%
r.render_calib_bandgapcontrol()

# %%
r.render_icalib()

# %%
r.render_clk()
# Out:
# <html><body><table><tr><th></th><th>Frequency (Hz)</th><th>Duty Cycle (%)</th></tr><tr><td>Internal</td><td>25427260</td><td>50</td></tr></table></body></html>
